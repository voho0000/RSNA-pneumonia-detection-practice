# %% [markdown]
# # load data
# # selecct normal data
# # train autoencoder
# # loss of AP and pneumonia

# %%
# %pip install -q "monai[pillow, tqdm]"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# FIXME: install MONAI from source code, will remove it when v0.4.0 released
# %pip install git+https://github.com/Project-MONAI/MONAI#egg=MONAI
# Out:
# Requirement already satisfied: MONAI from git+https://github.com/Project-MONAI/MONAI#egg=MONAI in /home/yihsin/anaconda3/lib/python3.7/site-packages (0.3.0)
# Requirement already satisfied: torch>=1.4 in /home/yihsin/anaconda3/lib/python3.7/site-packages (from MONAI) (1.6.0)
# Requirement already satisfied: numpy>=1.17 in /home/yihsin/anaconda3/lib/python3.7/site-packages (from MONAI) (1.17.2)
# Requirement already satisfied: future in /home/yihsin/anaconda3/lib/python3.7/site-packages (from torch>=1.4->MONAI) (0.18.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
import logging
import os
import shutil
import sys
import tempfile
import random
import numpy as np
from tqdm import trange
import matplotlib.pyplot as plt
import torch
from skimage.util import random_noise

# %%
from monai.transforms import (
    AddChannelD,
    Compose,
    LoadImageD,
    RandFlipD,
    RandRotateD,
    RandZoomD,
    ScaleIntensityD,
    ToTensorD,
    Lambda,
)
from monai.utils import set_determinism

# %%
from monai.transforms import (
    LoadImage,
    AddChannel,
    Compose,
    RandFlip,
    RandRotate,
    RandZoom,
    ScaleIntensity,
    ToTensor,
    Transform,
)
from monai.data import CacheDataset, DataLoader
from autoencoder import AutoEncoder

# %%
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
set_determinism(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
img_path = "../data/size512/stage_2_train_images"

# %%
df = pd.read_csv("../data/size1024/df_PA.csv")

# %%
PA_df = df[(df['ViewPosition']=='PA')&(df['class']=='Normal')]

# %%
PA_ID = list(PA_df['patientId'])

# %%
#PA_ID

# %%
img_list = [i for i in os.listdir(img_path) if i[:-4] in PA_ID]

# %%
all_filenames = [os.path.join(img_path ,i) for i in img_list]

# %%
test_frac = 0.2
num_test = int(len(all_filenames) * test_frac)
num_train = len(all_filenames) - num_test
train_datadict = [{"im": fname} for fname in all_filenames[:num_train]]
test_datadict = [{"im": fname} for fname in all_filenames[-num_test:]]

# %%
class LoadImage_m(Transform):
    def __call__(self, data):
        return plt.imread(data)

# %%
'''
NoiseLambda = Lambda(lambda d: {
    "orig":d["im"],
    "gaus":torch.tensor(random_noise(d["im"], mode='gaussian'), dtype=torch.float32),
    "s&p":torch.tensor(random_noise(d["im"], mode='s&p', salt_vs_pepper=0.1)),
})
'''
train_transforms = Compose(
    [
        LoadImageD(keys=["im"]),
        AddChannelD(keys=["im"]),
        ScaleIntensityD(keys=["im"]),
        RandRotateD(keys=["im"], range_x=np.pi / 12, prob=0.5, keep_size=True),
        RandFlipD(keys=["im"], spatial_axis=0, prob=0.5),
        RandZoomD(keys=["im"], min_zoom=0.9, max_zoom=1.1, prob=0.5),
        ToTensorD(keys=["im"]),
        #NoiseLambda,
    ]
)

test_transforms = Compose(
    [
        LoadImageD(keys=["im"]),
        AddChannelD(keys=["im"]),
        ScaleIntensityD(keys=["im"]),
        ToTensorD(keys=["im"]),
        #NoiseLambda,
    ]
)


batch_size = 4
num_workers = 6

train_ds = CacheDataset(train_datadict, train_transforms)
train_loader = torch.utils.data.DataLoader(
    train_ds, batch_size=batch_size, shuffle=True, num_workers=num_workers
)
# Out:
# '\ntrain_ds = CacheDataset(train_datadict, train_transforms)\ntrain_loader = torch.utils.data.DataLoader(\n    train_ds, batch_size=batch_size, shuffle=True, num_workers=num_workers\n)\n'

# %%
test_ds = CacheDataset(test_datadict, test_transforms, num_workers=num_workers)
test_loader = DataLoader(test_ds, batch_size=1, shuffle=True, num_workers=num_workers)
# Out:
# Load and cache transformed data:   0%|          | 0/1442 [00:00<?, ?it/s]
# Load and cache transformed data:   0%|          | 2/1442 [00:00<01:39, 14.49it/s]
# Load and cache transformed data:   1%|          | 8/1442 [00:00<01:18, 18.22it/s]
# Load and cache transformed data:   1%|          | 14/1442 [00:00<01:02, 22.80it/s]
# Load and cache transformed data:   1%|▏         | 21/1442 [00:00<00:51, 27.86it/s]
# Load and cache transformed data:   2%|▏         | 26/1442 [00:00<00:44, 31.79it/s]
# Load and cache transformed data:   2%|▏         | 32/1442 [00:00<00:39, 36.05it/s]
# Load and cache transformed data:   3%|▎         | 38/1442 [00:00<00:37, 37.61it/s]
# Load and cache transformed data:   3%|▎         | 45/1442 [00:00<00:32, 42.56it/s]
# Load and cache transformed data:   3%|▎         | 50/1442 [00:01<00:32, 43.18it/s]
# Load and cache transformed data:   4%|▍         | 56/1442 [00:01<00:30, 46.11it/s]
# Load and cache transformed data:   4%|▍         | 62/1442 [00:01<00:27, 49.39it/s]
# Load and cache transformed data:   5%|▍         | 68/1442 [00:01<00:27, 49.14it/s]
# Load and cache transformed data:   5%|▌         | 74/1442 [00:01<00:26, 51.69it/s]
# Load and cache transformed data:   6%|▌         | 80/1442 [00:01<00:25, 53.80it/s]
# Load and cache transformed data:   6%|▌         | 86/1442 [00:01<00:26, 51.72it/s]
# Load and cache transformed data:   6%|▋         | 92/1442 [00:01<00:25, 53.83it/s]
# Load and cache transformed data:   7%|▋         | 98/1442 [00:01<00:26, 50.90it/s]
# Load and cache transformed data:   7%|▋         | 104/1442 [00:02<00:25, 52.85it/s]
# Load and cache transformed data:   8%|▊         | 111/1442 [00:02<00:24, 54.57it/s]
# Load and cache transformed data:   8%|▊         | 118/1442 [00:02<00:23, 56.22it/s]
# Load and cache transformed data:   9%|▊         | 124/1442 [00:02<00:24, 54.40it/s]
# Load and cache transformed data:   9%|▉         | 130/1442 [00:02<00:23, 55.74it/s]
# Load and cache transformed data:  10%|▉         | 137/1442 [00:02<00:22, 56.95it/s]
# Load and cache transformed data:  10%|▉         | 143/1442 [00:02<00:22, 57.61it/s]
# Load and cache transformed data:  10%|█         | 149/1442 [00:02<00:22, 58.12it/s]
# Load and cache transformed data:  11%|█         | 155/1442 [00:02<00:22, 58.31it/s]
# Load and cache transformed data:  11%|█         | 161/1442 [00:03<00:22, 58.22it/s]
# Load and cache transformed data:  12%|█▏        | 167/1442 [00:03<00:21, 58.37it/s]
# Load and cache transformed data:  12%|█▏        | 173/1442 [00:03<00:22, 55.73it/s]
# Load and cache transformed data:  84%|████████▍ | 1211/1442 [00:23<00:04, 46.74it/s]
# Load and cache transformed data:  84%|████████▍ | 1217/1442 [00:23<00:04, 49.78it/s]
# Load and cache transformed data:  85%|████████▍ | 1223/1442 [00:23<00:04, 50.86it/s]
# Load and cache transformed data:  85%|████████▌ | 1229/1442 [00:23<00:04, 50.84it/s]
# Load and cache transformed data:  86%|████████▌ | 1235/1442 [00:23<00:04, 48.58it/s]
# Load and cache transformed data:  86%|████████▌ | 1240/1442 [00:23<00:04, 48.36it/s]
# Load and cache transformed data:  86%|████████▋ | 1245/1442 [00:23<00:04, 46.04it/s]
# Load and cache transformed data:  87%|████████▋ | 1250/1442 [00:23<00:04, 46.86it/s]
# Load and cache transformed data:  87%|████████▋ | 1257/1442 [00:23<00:03, 50.81it/s]
# Load and cache transformed data:  88%|████████▊ | 1263/1442 [00:24<00:03, 52.49it/s]
# Load and cache transformed data:  88%|████████▊ | 1269/1442 [00:24<00:03, 54.16it/s]
# Load and cache transformed data:  88%|████████▊ | 1275/1442 [00:24<00:03, 49.76it/s]
# Load and cache transformed data:  89%|████████▉ | 1281/1442 [00:24<00:03, 52.27it/s]
# Load and cache transformed data:  89%|████████▉ | 1287/1442 [00:24<00:02, 53.61it/s]
# Load and cache transformed data:  90%|████████▉ | 1293/1442 [00:24<00:02, 55.20it/s]
# Load and cache transformed data:  90%|█████████ | 1299/1442 [00:24<00:02, 54.69it/s]
# Load and cache transformed data:  91%|█████████ | 1306/1442 [00:24<00:02, 56.64it/s]
# Load and cache transformed data:  91%|█████████ | 1312/1442 [00:24<00:02, 56.63it/s]
# Load and cache transformed data:  91%|█████████▏| 1318/1442 [00:25<00:02, 56.94it/s]
# Load and cache transformed data:  92%|█████████▏| 1325/1442 [00:25<00:01, 58.77it/s]
# Load and cache transformed data:  92%|█████████▏| 1331/1442 [00:25<00:01, 58.50it/s]
# Load and cache transformed data:  93%|█████████▎| 1337/1442 [00:25<00:01, 56.90it/s]
# Load and cache transformed data:  93%|█████████▎| 1344/1442 [00:25<00:01, 57.54it/s]
# Load and cache transformed data:  94%|█████████▎| 1350/1442 [00:25<00:01, 56.73it/s]
# Load and cache transformed data:  94%|█████████▍| 1357/1442 [00:25<00:01, 57.31it/s]
# Load and cache transformed data:  95%|█████████▍| 1363/1442 [00:25<00:01, 57.24it/s]
# Load and cache transformed data:  95%|█████████▍| 1369/1442 [00:25<00:01, 57.02it/s]
# Load and cache transformed data:  95%|█████████▌| 1375/1442 [00:26<00:01, 57.03it/s]
# Load and cache transformed data:  96%|█████████▌| 1382/1442 [00:26<00:01, 58.05it/s]
# Load and cache transformed data:  96%|█████████▋| 1388/1442 [00:26<00:00, 58.35it/s]
# Load and cache transformed data:  97%|█████████▋| 1396/1442 [00:26<00:00, 59.24it/s]
# Load and cache transformed data:  97%|█████████▋| 1403/1442 [00:26<00:00, 59.58it/s]
# Load and cache transformed data:  98%|█████████▊| 1410/1442 [00:26<00:00, 59.65it/s]
# Load and cache transformed data:  98%|█████████▊| 1417/1442 [00:26<00:00, 61.45it/s]
# Load and cache transformed data:  99%|█████████▉| 1424/1442 [00:26<00:00, 60.32it/s]
# Load and cache transformed data:  99%|█████████▉| 1431/1442 [00:26<00:00, 60.68it/s]
# Load and cache transformed data: 100%|██████████| 1442/1442 [00:27<00:00, 53.13it/s]

# %%
def train(epoch_num=10, learning_rate=1e-3):
    
    model = AutoEncoder(
        dimensions=2,
        in_channels=1,
        out_channels=1,
        channels=(4, 8, 16, 32),
        strides=(2, 2, 2, 2),
    ).to(device)
    
        # Create loss fn and optimiser
    loss_function = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), learning_rate)

    epoch_loss_values = list()
    
    t = trange(epoch_num, desc=" -- epoch 0, avg loss: inf", leave=True)
    for epoch in t:
        model.train()
        epoch_loss = 0
        step = 0
        for batch_data in train_loader:        
            step += 1
            inputs = batch_data['im'].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = loss_function(outputs, batch_data['im'].to(device))
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            epoch_len = len(train_ds) // train_loader.batch_size
        epoch_loss /= step
        epoch_loss_values.append(epoch_loss)
        t.set_description(f" -- epoch {epoch + 1}, average loss: {epoch_loss:.4f}")
    
    torch.save(model.state_dict(), './model_PA.pth')
    
    return model, epoch_loss_values

# %%
model = AutoEncoder(
        dimensions=2,
        in_channels=1,
        out_channels=1,
        channels=(4, 8, 16, 32),
        strides=(2, 2, 2, 2),
    ).to(device)
model.load_state_dict(torch.load('./model.pth'))
# Out:
# <All keys matched successfully>

# %%
epoch_num = 20
models = []
epoch_losses = []

model, epoch_loss = train(epoch_num=epoch_num)
models.append(model)
epoch_losses.append(epoch_loss)

# %%
_, ax = plt.subplots(1,1,figsize=(10,5))
ax.set_title('Loss')
ax.plot(epoch_losses[0])

# %%
# Create small visualistaion function
def plot_ims(ims, shape=None, figsize=(10,10), titles=None):
    shape = (1,len(ims)) if shape is None else shape
    plt.subplots(*shape, figsize=figsize)
    for i,im in enumerate(ims):
        plt.subplot(*shape,i+1)
        im = plt.imread(im) if isinstance(im, str) else torch.squeeze(im)
        plt.imshow(im, cmap='gray')
        if titles is not None:
            plt.title(titles[i])
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
# Get image original and its degraded versions
def get_single_im(ds):
    loader = torch.utils.data.DataLoader(ds, batch_size=1, num_workers=10, shuffle=True)
    itera = iter(loader)
    return next(itera)

# %%
data = get_single_im(test_ds)

model.eval()
recons = []
im = data['im']
recon = model(im.to(device)).detach().cpu()
recons.append(recon)

plot_ims(
    [im] + [recons[0]], 
    titles=['orig'] + ["recon"] ,
    shape=(2,1))

# %% [markdown]
# ## PA_pnemonia dataset

# %%
df = pd.read_csv("../data/final_df.csv")
img_path = "../data/size512/stage_2_train_images"

# %%
PA_opacity_df = df[(df['ViewPosition']=='PA')&(df['class']=='Lung Opacity')]

# %%
len(PA_opacity_df)
# Out:
# 1767

# %%
PA_opacity_ID = list(PA_opacity_df['patientId'])
img_list = [i for i in os.listdir(img_path) if i[:-4] in PA_opacity_ID]
all_filenames = [os.path.join(img_path ,i) for i in img_list]

# %%
len(PA_opacity_ID)
# Out:
# 1767

# %%
len(all_filenames)
# Out:
# 1348

# %%
PA_opacity_test_datadict = [{"im": fname} for fname in all_filenames]

# %%
num_workers = 4
PA_opacity_test_ds = CacheDataset(PA_opacity_test_datadict, test_transforms, num_workers=num_workers)
PA_opacity_test_loader = DataLoader(PA_opacity_test_ds, batch_size=1, shuffle=True, num_workers=num_workers)
# Out:
# Load and cache transformed data:   0%|          | 0/1348 [00:00<?, ?it/s]
# Load and cache transformed data:   0%|          | 4/1348 [00:00<00:37, 35.58it/s]
# Load and cache transformed data:   1%|          | 10/1348 [00:00<00:33, 40.38it/s]
# Load and cache transformed data:   1%|          | 16/1348 [00:00<00:30, 44.25it/s]
# Load and cache transformed data:   2%|▏         | 22/1348 [00:00<00:27, 47.65it/s]
# Load and cache transformed data:   2%|▏         | 28/1348 [00:00<00:26, 50.40it/s]
# Load and cache transformed data:   3%|▎         | 34/1348 [00:00<00:24, 52.79it/s]
# Load and cache transformed data:   3%|▎         | 40/1348 [00:00<00:25, 52.24it/s]
# Load and cache transformed data:   3%|▎         | 46/1348 [00:00<00:24, 53.93it/s]
# Load and cache transformed data:   4%|▍         | 53/1348 [00:00<00:23, 55.61it/s]
# Load and cache transformed data:   4%|▍         | 60/1348 [00:01<00:22, 57.63it/s]
# Load and cache transformed data:   5%|▍         | 66/1348 [00:01<00:22, 57.30it/s]
# Load and cache transformed data:   5%|▌         | 72/1348 [00:01<00:22, 55.67it/s]
# Load and cache transformed data:   6%|▌         | 78/1348 [00:01<00:22, 55.77it/s]
# Load and cache transformed data:   6%|▋         | 85/1348 [00:01<00:22, 55.90it/s]
# Load and cache transformed data:   7%|▋         | 92/1348 [00:01<00:21, 58.03it/s]
# Load and cache transformed data:   7%|▋         | 98/1348 [00:01<00:21, 57.84it/s]
# Load and cache transformed data:   8%|▊         | 105/1348 [00:01<00:21, 59.19it/s]
# Load and cache transformed data:   8%|▊         | 112/1348 [00:01<00:20, 59.31it/s]
# Load and cache transformed data:   9%|▉         | 118/1348 [00:02<00:20, 59.34it/s]
# Load and cache transformed data:   9%|▉         | 124/1348 [00:02<00:21, 57.05it/s]
# Load and cache transformed data:  10%|▉         | 130/1348 [00:02<00:22, 54.50it/s]
# Load and cache transformed data:  10%|█         | 136/1348 [00:02<00:21, 56.01it/s]
# Load and cache transformed data:  11%|█         | 142/1348 [00:02<00:22, 54.25it/s]
# Load and cache transformed data:  11%|█         | 148/1348 [00:02<00:21, 55.58it/s]
# Load and cache transformed data:  11%|█▏        | 154/1348 [00:02<00:21, 55.70it/s]
# Load and cache transformed data:  12%|█▏        | 160/1348 [00:02<00:21, 55.84it/s]
# Load and cache transformed data:  12%|█▏        | 166/1348 [00:02<00:21, 56.25it/s]
# Load and cache transformed data:  13%|█▎        | 172/1348 [00:03<00:20, 57.11it/s]
# Load and cache transformed data:  13%|█▎        | 178/1348 [00:03<00:20, 57.21it/s]
# Load and cache transformed data:  14%|█▎        | 185/1348 [00:03<00:19, 58.43it/s]
# Load and cache transformed data:  14%|█▍        | 192/1348 [00:03<00:19, 59.46it/s]
# Load and cache transformed data:  15%|█▍        | 199/1348 [00:03<00:18, 60.76it/s]
# Load and cache transformed data:  15%|█▌        | 206/1348 [00:03<00:18, 60.44it/s]
# Load and cache transformed data:  16%|█▌        | 213/1348 [00:03<00:18, 60.18it/s]
# Load and cache transformed data:  16%|█▋        | 220/1348 [00:03<00:18, 59.83it/s]
# Load and cache transformed data:  17%|█▋        | 226/1348 [00:03<00:18, 59.49it/s]
# Load and cache transformed data:  17%|█▋        | 232/1348 [00:04<00:20, 55.10it/s]
# Load and cache transformed data:  18%|█▊        | 238/1348 [00:04<00:19, 56.36it/s]
# Load and cache transformed data:  18%|█▊        | 244/1348 [00:04<00:19, 56.95it/s]
# Load and cache transformed data:  19%|█▊        | 250/1348 [00:04<00:19, 57.11it/s]
# Load and cache transformed data:  19%|█▉        | 256/1348 [00:04<00:19, 57.36it/s]
# Load and cache transformed data:  19%|█▉        | 262/1348 [00:04<00:18, 57.59it/s]
# Load and cache transformed data:  20%|█▉        | 268/1348 [00:04<00:18, 58.15it/s]
# Load and cache transformed data:  20%|██        | 274/1348 [00:04<00:18, 58.02it/s]
# Load and cache transformed data:  21%|██        | 280/1348 [00:04<00:18, 58.06it/s]
# Load and cache transformed data:  21%|██        | 286/1348 [00:05<00:18, 57.56it/s]
# Load and cache transformed data:  22%|██▏       | 292/1348 [00:05<00:18, 56.73it/s]
# Load and cache transformed data:  22%|██▏       | 299/1348 [00:05<00:18, 57.94it/s]
# Load and cache transformed data:  23%|██▎       | 305/1348 [00:05<00:18, 57.79it/s]
# Load and cache transformed data:  23%|██▎       | 312/1348 [00:05<00:17, 59.18it/s]
# Load and cache transformed data:  24%|██▎       | 318/1348 [00:05<00:18, 55.12it/s]
# Load and cache transformed data:  24%|██▍       | 324/1348 [00:05<00:18, 54.38it/s]
# Load and cache transformed data:  25%|██▍       | 331/1348 [00:05<00:17, 56.57it/s]
# Load and cache transformed data:  25%|██▌       | 337/1348 [00:05<00:17, 56.82it/s]
# Load and cache transformed data:  25%|██▌       | 343/1348 [00:06<00:19, 51.55it/s]
# Load and cache transformed data:  26%|██▌       | 349/1348 [00:06<00:20, 49.05it/s]
# Load and cache transformed data:  26%|██▋       | 355/1348 [00:06<00:19, 51.85it/s]
# Load and cache transformed data:  27%|██▋       | 361/1348 [00:06<00:18, 53.91it/s]
# Load and cache transformed data:  27%|██▋       | 368/1348 [00:06<00:17, 56.12it/s]
# Load and cache transformed data:  28%|██▊       | 374/1348 [00:06<00:17, 55.44it/s]
# Load and cache transformed data:  28%|██▊       | 381/1348 [00:06<00:16, 57.67it/s]
# Load and cache transformed data:  29%|██▊       | 387/1348 [00:06<00:16, 58.02it/s]
# Load and cache transformed data:  29%|██▉       | 393/1348 [00:06<00:16, 57.81it/s]
# Load and cache transformed data:  30%|██▉       | 399/1348 [00:07<00:16, 56.26it/s]
# Load and cache transformed data:  30%|███       | 405/1348 [00:07<00:16, 56.13it/s]
# Load and cache transformed data:  30%|███       | 411/1348 [00:07<00:16, 56.65it/s]
# Load and cache transformed data:  31%|███       | 418/1348 [00:07<00:15, 58.43it/s]
# Load and cache transformed data:  31%|███▏      | 424/1348 [00:07<00:15, 58.15it/s]
# Load and cache transformed data:  32%|███▏      | 430/1348 [00:07<00:16, 56.11it/s]
# Load and cache transformed data:  32%|███▏      | 437/1348 [00:07<00:15, 57.86it/s]
# Load and cache transformed data:  33%|███▎      | 443/1348 [00:07<00:16, 56.20it/s]
# Load and cache transformed data:  33%|███▎      | 449/1348 [00:07<00:17, 51.44it/s]
# Load and cache transformed data:  34%|███▍      | 456/1348 [00:08<00:16, 54.13it/s]
# Load and cache transformed data:  34%|███▍      | 463/1348 [00:08<00:15, 56.36it/s]
# Load and cache transformed data:  35%|███▍      | 469/1348 [00:08<00:15, 57.12it/s]
# Load and cache transformed data:  35%|███▌      | 476/1348 [00:08<00:14, 58.56it/s]
# Load and cache transformed data:  36%|███▌      | 483/1348 [00:08<00:14, 60.13it/s]
# Load and cache transformed data:  36%|███▋      | 490/1348 [00:08<00:14, 59.97it/s]
# Load and cache transformed data:  37%|███▋      | 497/1348 [00:08<00:14, 59.73it/s]
# Load and cache transformed data:  37%|███▋      | 503/1348 [00:08<00:14, 59.65it/s]
# Load and cache transformed data:  38%|███▊      | 509/1348 [00:08<00:14, 59.23it/s]
# Load and cache transformed data:  38%|███▊      | 515/1348 [00:09<00:14, 59.18it/s]
# Load and cache transformed data:  39%|███▊      | 521/1348 [00:09<00:14, 59.00it/s]
# Load and cache transformed data:  39%|███▉      | 527/1348 [00:09<00:14, 58.48it/s]
# Load and cache transformed data:  40%|███▉      | 533/1348 [00:09<00:13, 58.41it/s]
# Load and cache transformed data:  40%|████      | 540/1348 [00:09<00:13, 58.72it/s]
# Load and cache transformed data:  41%|████      | 547/1348 [00:09<00:13, 59.49it/s]
# Load and cache transformed data:  41%|████      | 553/1348 [00:09<00:13, 57.96it/s]
# Load and cache transformed data:  41%|████▏     | 559/1348 [00:09<00:14, 54.16it/s]
# Load and cache transformed data:  42%|████▏     | 565/1348 [00:09<00:14, 55.05it/s]
# Load and cache transformed data:  42%|████▏     | 571/1348 [00:10<00:14, 55.44it/s]
# Load and cache transformed data:  43%|████▎     | 577/1348 [00:10<00:14, 53.35it/s]
# Load and cache transformed data:  43%|████▎     | 583/1348 [00:10<00:14, 54.63it/s]
# Load and cache transformed data:  44%|████▎     | 589/1348 [00:10<00:13, 55.79it/s]
# Load and cache transformed data:  44%|████▍     | 595/1348 [00:10<00:13, 56.71it/s]
# Load and cache transformed data:  45%|████▍     | 601/1348 [00:10<00:13, 57.05it/s]
# Load and cache transformed data:  45%|████▌     | 607/1348 [00:10<00:13, 56.83it/s]
# Load and cache transformed data:  45%|████▌     | 613/1348 [00:10<00:12, 57.71it/s]
# Load and cache transformed data:  46%|████▌     | 620/1348 [00:10<00:12, 58.57it/s]
# Load and cache transformed data:  46%|████▋     | 626/1348 [00:10<00:12, 58.17it/s]
# Load and cache transformed data:  47%|████▋     | 632/1348 [00:11<00:12, 57.15it/s]
# Load and cache transformed data:  47%|████▋     | 638/1348 [00:11<00:12, 57.47it/s]
# Load and cache transformed data:  48%|████▊     | 644/1348 [00:11<00:12, 57.78it/s]
# Load and cache transformed data:  48%|████▊     | 650/1348 [00:11<00:12, 56.56it/s]
# Load and cache transformed data:  49%|████▊     | 656/1348 [00:11<00:12, 56.71it/s]
# Load and cache transformed data:  49%|████▉     | 662/1348 [00:11<00:12, 55.70it/s]
# Load and cache transformed data:  50%|████▉     | 668/1348 [00:11<00:12, 54.31it/s]
# Load and cache transformed data:  50%|█████     | 674/1348 [00:11<00:13, 51.05it/s]
# Load and cache transformed data:  50%|█████     | 680/1348 [00:12<00:13, 50.34it/s]
# Load and cache transformed data:  51%|█████     | 686/1348 [00:12<00:13, 49.06it/s]
# Load and cache transformed data:  51%|█████▏    | 692/1348 [00:12<00:12, 50.84it/s]
# Load and cache transformed data:  52%|█████▏    | 698/1348 [00:12<00:12, 52.32it/s]
# Load and cache transformed data:  52%|█████▏    | 704/1348 [00:12<00:12, 52.43it/s]
# Load and cache transformed data:  53%|█████▎    | 710/1348 [00:12<00:11, 53.64it/s]
# Load and cache transformed data:  53%|█████▎    | 717/1348 [00:12<00:11, 55.52it/s]
# Load and cache transformed data:  54%|█████▎    | 723/1348 [00:12<00:11, 56.62it/s]
# Load and cache transformed data:  54%|█████▍    | 729/1348 [00:12<00:10, 56.72it/s]
# Load and cache transformed data:  55%|█████▍    | 735/1348 [00:12<00:10, 56.20it/s]
# Load and cache transformed data:  55%|█████▍    | 741/1348 [00:13<00:10, 56.58it/s]
# Load and cache transformed data:  55%|█████▌    | 748/1348 [00:13<00:10, 57.96it/s]
# Load and cache transformed data:  56%|█████▌    | 754/1348 [00:13<00:10, 57.94it/s]
# Load and cache transformed data:  56%|█████▋    | 761/1348 [00:13<00:10, 58.63it/s]
# Load and cache transformed data:  57%|█████▋    | 767/1348 [00:13<00:10, 57.27it/s]
# Load and cache transformed data:  57%|█████▋    | 773/1348 [00:13<00:10, 55.02it/s]
# Load and cache transformed data:  58%|█████▊    | 779/1348 [00:13<00:10, 54.79it/s]
# Load and cache transformed data:  58%|█████▊    | 785/1348 [00:13<00:10, 55.13it/s]
# Load and cache transformed data:  59%|█████▊    | 791/1348 [00:13<00:10, 55.43it/s]
# Load and cache transformed data:  59%|█████▉    | 797/1348 [00:14<00:09, 55.31it/s]
# Load and cache transformed data:  60%|█████▉    | 803/1348 [00:14<00:10, 53.90it/s]
# Load and cache transformed data:  60%|██████    | 810/1348 [00:14<00:09, 56.51it/s]
# Load and cache transformed data:  61%|██████    | 816/1348 [00:14<00:09, 57.49it/s]
# Load and cache transformed data:  61%|██████    | 822/1348 [00:14<00:09, 56.29it/s]
# Load and cache transformed data:  61%|██████▏   | 829/1348 [00:14<00:09, 56.74it/s]
# Load and cache transformed data:  62%|██████▏   | 835/1348 [00:14<00:09, 55.36it/s]
# Load and cache transformed data:  62%|██████▏   | 841/1348 [00:14<00:09, 52.91it/s]
# Load and cache transformed data:  63%|██████▎   | 847/1348 [00:15<00:09, 51.63it/s]
# Load and cache transformed data:  63%|██████▎   | 853/1348 [00:15<00:09, 52.70it/s]
# Load and cache transformed data:  64%|██████▎   | 859/1348 [00:15<00:09, 51.86it/s]
# Load and cache transformed data:  64%|██████▍   | 865/1348 [00:15<00:09, 52.39it/s]
# Load and cache transformed data:  65%|██████▍   | 872/1348 [00:15<00:08, 54.73it/s]
# Load and cache transformed data:  65%|██████▌   | 878/1348 [00:15<00:08, 54.25it/s]
# Load and cache transformed data:  66%|██████▌   | 885/1348 [00:15<00:08, 55.30it/s]
# Load and cache transformed data:  66%|██████▌   | 891/1348 [00:15<00:08, 56.21it/s]
# Load and cache transformed data:  67%|██████▋   | 897/1348 [00:15<00:07, 57.23it/s]
# Load and cache transformed data:  67%|██████▋   | 904/1348 [00:16<00:07, 58.66it/s]
# Load and cache transformed data:  68%|██████▊   | 910/1348 [00:16<00:07, 55.79it/s]
# Load and cache transformed data:  68%|██████▊   | 916/1348 [00:16<00:07, 55.88it/s]
# Load and cache transformed data:  68%|██████▊   | 922/1348 [00:16<00:08, 53.19it/s]
# Load and cache transformed data:  69%|██████▉   | 928/1348 [00:16<00:07, 53.87it/s]
# Load and cache transformed data:  69%|██████▉   | 934/1348 [00:16<00:09, 45.97it/s]
# Load and cache transformed data:  70%|██████▉   | 939/1348 [00:16<00:08, 45.56it/s]
# Load and cache transformed data:  70%|███████   | 945/1348 [00:16<00:08, 46.56it/s]
# Load and cache transformed data:  71%|███████   | 952/1348 [00:17<00:07, 49.76it/s]
# Load and cache transformed data:  71%|███████   | 959/1348 [00:17<00:07, 53.17it/s]
# Load and cache transformed data:  72%|███████▏  | 965/1348 [00:17<00:07, 52.37it/s]
# Load and cache transformed data:  72%|███████▏  | 971/1348 [00:17<00:06, 54.22it/s]
# Load and cache transformed data:  73%|███████▎  | 978/1348 [00:17<00:06, 55.19it/s]
# Load and cache transformed data:  73%|███████▎  | 984/1348 [00:17<00:07, 51.50it/s]
# Load and cache transformed data:  73%|███████▎  | 990/1348 [00:17<00:06, 52.18it/s]
# Load and cache transformed data:  74%|███████▍  | 996/1348 [00:17<00:06, 54.10it/s]
# Load and cache transformed data:  74%|███████▍  | 1002/1348 [00:17<00:06, 51.64it/s]
# Load and cache transformed data:  75%|███████▍  | 1009/1348 [00:18<00:06, 54.46it/s]
# Load and cache transformed data:  75%|███████▌  | 1015/1348 [00:18<00:05, 55.65it/s]
# Load and cache transformed data:  76%|███████▌  | 1021/1348 [00:18<00:05, 55.90it/s]
# Load and cache transformed data:  76%|███████▋  | 1028/1348 [00:18<00:05, 57.05it/s]
# Load and cache transformed data:  77%|███████▋  | 1034/1348 [00:18<00:05, 57.51it/s]
# Load and cache transformed data:  77%|███████▋  | 1040/1348 [00:18<00:05, 55.36it/s]
# Load and cache transformed data:  78%|███████▊  | 1046/1348 [00:18<00:05, 55.90it/s]
# Load and cache transformed data:  78%|███████▊  | 1052/1348 [00:18<00:05, 56.75it/s]
# Load and cache transformed data:  78%|███████▊  | 1058/1348 [00:18<00:05, 56.42it/s]
# Load and cache transformed data:  79%|███████▉  | 1064/1348 [00:19<00:05, 56.63it/s]
# Load and cache transformed data:  79%|███████▉  | 1070/1348 [00:19<00:04, 56.42it/s]
# Load and cache transformed data:  80%|███████▉  | 1076/1348 [00:19<00:04, 56.68it/s]
# Load and cache transformed data:  80%|████████  | 1082/1348 [00:19<00:04, 54.48it/s]
# Load and cache transformed data:  81%|████████  | 1088/1348 [00:19<00:04, 55.49it/s]
# Load and cache transformed data:  81%|████████  | 1094/1348 [00:19<00:04, 56.40it/s]
# Load and cache transformed data:  82%|████████▏ | 1100/1348 [00:19<00:04, 57.00it/s]
# Load and cache transformed data:  82%|████████▏ | 1106/1348 [00:19<00:04, 57.72it/s]
# Load and cache transformed data:  82%|████████▏ | 1112/1348 [00:19<00:04, 58.19it/s]
# Load and cache transformed data:  83%|████████▎ | 1118/1348 [00:19<00:04, 55.47it/s]
# Load and cache transformed data:  83%|████████▎ | 1124/1348 [00:20<00:03, 56.23it/s]
# Load and cache transformed data:  84%|████████▍ | 1130/1348 [00:20<00:03, 56.72it/s]
# Load and cache transformed data:  84%|████████▍ | 1137/1348 [00:20<00:03, 57.45it/s]
# Load and cache transformed data:  85%|████████▍ | 1143/1348 [00:20<00:03, 54.05it/s]
# Load and cache transformed data:  85%|████████▌ | 1149/1348 [00:20<00:03, 55.60it/s]
# Load and cache transformed data:  86%|████████▌ | 1156/1348 [00:20<00:03, 56.75it/s]
# Load and cache transformed data:  86%|████████▌ | 1162/1348 [00:20<00:03, 57.35it/s]
# Load and cache transformed data:  87%|████████▋ | 1168/1348 [00:20<00:03, 57.38it/s]
# Load and cache transformed data:  87%|████████▋ | 1175/1348 [00:20<00:02, 58.05it/s]
# Load and cache transformed data:  88%|████████▊ | 1182/1348 [00:21<00:02, 57.44it/s]
# Load and cache transformed data:  88%|████████▊ | 1188/1348 [00:21<00:02, 56.98it/s]
# Load and cache transformed data:  89%|████████▊ | 1194/1348 [00:21<00:02, 57.00it/s]
# Load and cache transformed data:  89%|████████▉ | 1201/1348 [00:21<00:02, 57.75it/s]
# Load and cache transformed data:  90%|████████▉ | 1207/1348 [00:21<00:02, 57.64it/s]
# Load and cache transformed data:  90%|████████▉ | 1213/1348 [00:21<00:02, 55.50it/s]
# Load and cache transformed data:  91%|█████████ | 1220/1348 [00:21<00:02, 56.00it/s]
# Load and cache transformed data:  91%|█████████ | 1227/1348 [00:21<00:02, 57.73it/s]
# Load and cache transformed data:  91%|█████████▏| 1233/1348 [00:21<00:01, 58.16it/s]
# Load and cache transformed data:  92%|█████████▏| 1239/1348 [00:22<00:01, 57.06it/s]
# Load and cache transformed data:  92%|█████████▏| 1245/1348 [00:22<00:01, 56.99it/s]
# Load and cache transformed data:  93%|█████████▎| 1251/1348 [00:22<00:01, 52.02it/s]
# Load and cache transformed data:  93%|█████████▎| 1257/1348 [00:22<00:01, 50.17it/s]
# Load and cache transformed data:  94%|█████████▎| 1263/1348 [00:22<00:01, 50.13it/s]
# Load and cache transformed data:  94%|█████████▍| 1269/1348 [00:22<00:01, 50.06it/s]
# Load and cache transformed data:  95%|█████████▍| 1276/1348 [00:22<00:01, 52.53it/s]
# Load and cache transformed data:  95%|█████████▌| 1282/1348 [00:22<00:01, 54.05it/s]
# Load and cache transformed data:  96%|█████████▌| 1289/1348 [00:23<00:01, 56.27it/s]
# Load and cache transformed data:  96%|█████████▌| 1295/1348 [00:23<00:00, 57.18it/s]
# Load and cache transformed data:  97%|█████████▋| 1301/1348 [00:23<00:00, 57.39it/s]
# Load and cache transformed data:  97%|█████████▋| 1307/1348 [00:23<00:00, 55.86it/s]
# Load and cache transformed data:  97%|█████████▋| 1313/1348 [00:23<00:00, 53.13it/s]
# Load and cache transformed data:  98%|█████████▊| 1319/1348 [00:23<00:00, 53.25it/s]
# Load and cache transformed data:  98%|█████████▊| 1325/1348 [00:23<00:00, 52.54it/s]
# Load and cache transformed data:  99%|█████████▊| 1331/1348 [00:23<00:00, 53.42it/s]
# Load and cache transformed data:  99%|█████████▉| 1337/1348 [00:23<00:00, 54.87it/s]
# Load and cache transformed data: 100%|██████████| 1348/1348 [00:24<00:00, 55.67it/s]

# %%
model = AutoEncoder(
        dimensions=2,
        in_channels=1,
        out_channels=1,
        channels=(4, 8, 16, 32),
        strides=(2, 2, 2, 2),
    ).to(device)
model.load_state_dict(torch.load('./model.pth'))
# Out:
# <All keys matched successfully>

# %%
def evaluation(dataset_type):
    model.eval()
    loss_dist = []
    loss_function = torch.nn.MSELoss()

    for batch_data in dataset_type:        
        inputs = batch_data['im'].to(device)
        outputs = model(inputs)
        loss = loss_function(outputs, batch_data['im'].to(device))
        loss_dist.append(loss.item())
        
    return loss_dist

# %%
test_types = ['PA','PA_opacity']
test_dataset_types = [test_loader, PA_opacity_test_loader]
test_losses = []
for i in test_dataset_types:
    test_loss = evaluation(i)
    test_losses.append(test_loss)

# %%
plt.figure()
for y, label in zip(test_losses, test_types):
    x = list(range(1, len(y)+1))
    line, = plt.plot(x, y)
    line.set_label(label)
plt.legend();

# %%
data = get_single_im(PA_opacity_test_ds)

model.eval()
recons = []
im = data['im']
recon = model(im.to(device)).detach().cpu()
recons.append(recon)

plot_ims(
    [im] + [recons[0]], 
    titles=['orig'] + ["recon"] ,
    shape=(2,1))

# %%
import seaborn as sns

# %%
lower_threshold = 0.0
upper_threshold = 0.0015
plt.figure(figsize=(12,6))
plt.title('Loss Distribution')
sns.distplot(test_losses[0],bins=100,kde=True, color='blue')
sns.distplot(test_losses[1],bins=100,kde=True, color='orange')
#plt.axvline(upper_threshold, 0.0, 10, color='r')
plt.axvline(lower_threshold, 0.0, 10, color='b')

# %% [markdown]
# ## ROC AUC

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
len(test_loader)
# Out:
# 1442

# %%
len(PA_opacity_test_loader)
# Out:
# 1348

# %%
y_test = [0]*len(test_losses[0]) + [1]*len(test_losses[1])
y_pred = test_losses[0] + test_losses[1]
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
# calculate AUC
auc = roc_auc_score(y_test, y_pred)
print('AUC: %.3f' % auc)
# Out:
# AUC: 0.541

# %%
plt.plot(fpr,tpr,label="data 2, auc="+str(auc))
plt.plot([0, 1], [0, 1], 'k--')
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
